# %% [markdown]
# <a href="https://colab.research.google.com/github/jcd1141/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# 1/20/26
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
# Basic print statements
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables
favorite_food = "chicken alfredo"
favorite_number = 2
favorite_color = "blue"

print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: chicken alfredo
# My favorite number is: 2
# My favorite color is: blue

# %%
points_scored = 490
points_against = 320
point_differential = points_scored - points_against

print("The Patriots point differential for the 2025-26 season was: " + str(point_differential) + ", with " + str(points_scored) + " points scored and " + str(points_against) + " points scored against them.")
# Out:
# The Patriots point differential for the 2025-26 season was: 170, with 490 points scored and 320 points scored against them.
